# %% [markdown]
# <div style="border:solid black 2px; padding: 20px"><h1 style="color:green; margin-bottom:20px">Reviewer's comment v1</h1>
# Halo Syaid!
#
# Perkenalkan saya Naufal, disini saya akan mereview tugas Syaid ya.
#
# Saya akan memberikan beberapa komen seperti dibawah ini, tolong jangan dipindah, dirubah, maupun dihapus ya.
#
# Komen yang saya berikan akan muncul dalam warna hijau, kuning, atau pun merah seperti ini:
#
# <div class="alert alert-success">
# <b>Reviewer's comment</b> <a class="tocSkip"></a>
#
# Bagus, semua berjalan lancar.
#
# </div>
#
# <div class="alert alert-warning">
# <b>Reviewer's comment</b> <a class="tocSkip"></a>
#
# Terdapat beberapa catatan.
#
# </div>
#
# <div class="alert alert-danger">
# <b>Reviewer's comment</b> <a class="tocSkip"></a>
#
# Perlu beberapa perbaikan
#
# </div>
#
# Dan tentu saja Syaid dapat menjawab saya dengan menggunakan ini
#
# <div class="alert alert-block alert-info">
# <b>Student answer.</b> <a class="tocSkip"></a>
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <b>Reviewer's comment v1</b> <a class="tocSkip"></a>
#
# Project ini masih belum bisa saya review karena masih banyak hasil tanpa penjelasan dari Syaid selain dari instruksi-instruksi yang ada. Sebelum melangkah lebih jauh dalam project ini, instruksi atau petunjuk yang ditandai dalam `[]` bisa dihapus ya. Sebaiknya Roby menjelaskan terkait projek ini terkait tujuan dan langkah-langkah yang akan diambil dalam pengerjaanya.
#
#     [Sebelum Anda memasuki analisis data Anda, jelaskan kepada diri Anda tujuan proyek dan langkah-langkah yang akan Anda lakukan.]
#     [Sebelum menyerahkan proyek Anda, pastikan Anda menghapus semua petunjuk dan deskripsi yang diberikan kepada Anda. Buat laporan ini seolah-olah Anda mengirimnya ke rekan tim Anda untuk menunjukkan apa yang Anda temukan - mereka seharusnya tidak tahu bahwa Anda mendapat bantuan eksternal dari kami! Untuk membantu Anda, kami telah memberikan petunjuk apa yang harus Anda hapus dalam tanda kurung siku.]
#
# </div>

# %% [markdown]
# # Menganalisis risiko peminjam gagal membayar
#
# Proyek Anda ialah menyiapkan laporan untuk bank bagian kredit. Anda harus mencari tahu pengaruh status perkawinan seorang nasabah dan jumlah anak terhadap probabilitas ketepatan waktu dalam melunasi pinjaman. Bank sudah memiliki beberapa data mengenai kelayakan kredit nasabah.
#
# Laporan Anda akan dipertimbangkan pada saat membuat **penilaian kredit** untuk calon nasabah. **Penilaian kredit** digunakan untuk mengevaluasi kemampuan calon peminjam untuk melunasi pinjaman mereka.
#
# [Dalam notebook ini Anda diberikan petunjuk dan instruksi singkat serta petunjuk untuk berfikir. Jangan abaikan petunjuk tersebut karena mereka dirancang untuk melengkapi Anda dengan struktur proyek dan akan membantu Anda menganalisis apa yang Anda lakukan secara mendalam. Sebelum menyerahkan proyek Anda, pastikan Anda menghapus semua petunjuk dan deskripsi yang diberikan kepada Anda. Buat laporan ini seolah-olah Anda mengirimnya ke rekan tim Anda untuk menunjukkan apa yang Anda temukan - mereka seharusnya tidak tahu bahwa Anda mendapat bantuan eksternal dari kami! Untuk membantu Anda, kami telah memberikan petunjuk apa yang harus Anda hapus dalam tanda kurung siku.]
#
# [Sebelum Anda memasuki analisis data Anda, jelaskan kepada diri Anda tujuan proyek dan langkah-langkah yang akan Anda lakukan.]

# %% [markdown]
# ## Buka *file* data dan baca informasi umumnya.
#
# [Mulai dengan mengimpor perpustakaan dan memuat data. Anda mungkin akan menyadari bahwa Anda memerlukan perpustakaan tambahan saat Anda menjalankan proyek, dan itu merupakan hal yang normal - hanya saja pastikan untuk memperbaharui bagian ini saat Anda melakukannya.]

# %%
# Memuat semua perpustakaan
import pandas as pd

# muat data
df = pd.read_csv('/datasets/credit_scoring_eng.csv')

# %% [markdown]
# <div class="alert alert-danger">
# <b>Reviewer's comment v1</b> <a class="tocSkip"></a>
#
# Akan lebih baik lagi apabila langkah memuat library dan data dipisah di dua sel yang berbeda. Hal ini akan meminimalisir perulangan ketika dilakukan muat ulang data saja tanpa muat ulang library yang sudah termuat sebelumnya.
#
# </div>

# %% [markdown]
# ## Soal 1. Eksplorasi Data
#
# **Deskripsi Data**
# - *`children`* - jumlah anak dalam keluarga
# - *`days_employed`* - pengalaman kerja dalam hari
# - *`dob_years`* - usia klien dalam tahun
# - *`education`* - pendidikan klien
# - *`education_id`* - tanda pengenal pendidikan
# - *`family_status`* - status perkawinan
# - *`family_status_id`* - tanda pengenal status perkawinan
# - *`gender`* - jenis kelamin klien
# - *`income_type`* - jenis pekerjaan
# - *`debt`* - apakah klien memiliki hutang pembayaran pinjaman
# - *`total_income`* - pendapatan bulanan
# - *`purpose`* - tujuan mendapatkan pinjaman
#
# [Sekarang saatnya mengeksplor data kita. Anda ingin melihat berapa banyak kolom dan baris yang tersedia, lihat beberapa baris untuk memeriksa potensi masalah dengan data.]

# %%
# Mari kita lihat berapa banyak baris dan kolom yang dimiliki oleh dataset kita
df.shape
# Out:
# (21525, 12)

# %%
# mari menampilkan N baris pertama
df.head(10)
# Out:
#    children  days_employed  dob_years            education  education_id  \
# 0         1   -8437.673028         42    bachelor's degree             0
# 1         1   -4024.803754         36  secondary education             1
# 2         0   -5623.422610         33  Secondary Education             1
# 3         3   -4124.747207         32  secondary education             1
# 4         0  340266.072047         53  secondary education             1
# 5         0    -926.185831         27    bachelor's degree             0
# 6         0   -2879.202052         43    bachelor's degree             0
# 7         0    -152.779569         50  SECONDARY EDUCATION             1
# 8         2   -6929.865299         35    BACHELOR'S DEGREE             0
# 9         0   -2188.756445         41  secondary education             1
#
#        family_status  family_status_id gender income_type  debt  total_income  \
# 0            married                 0      F    employee     0     40620.102
# 1            married                 0      F    employee     0     17932.802
# 2            married                 0      M    employee     0     23341.752
# 3            married                 0      M    employee     0     42820.568
# 4  civil partnership                 1      F     retiree     0     25378.572
# 5  civil partnership                 1      M    business     0     40922.170
# 6            married                 0      F    business     0     38484.156
# 7            married                 0      M    employee     0     21731.829
# 8  civil partnership                 1      F    employee     0     15337.093
# 9            married                 0      M    employee     0     23108.150
#
#                                purpose
# 0                purchase of the house
# 1                         car purchase
# 2                purchase of the house
# 3              supplementary education
# 4                    to have a wedding
# 5                purchase of the house
# 6                 housing transactions
# 7                            education
# 8                     having a wedding
# 9  purchase of the house for my family

# %% [markdown]
# <div class="alert alert-success">
# <b>Reviewer's comment v1</b> <a class="tocSkip"></a>
#
# OK!
#
# </div>

# %% [markdown]
# [Jelaskan apa yang Anda lihat dan perhatikan dalam sampel data yang Anda tampilkan. Apakah terdapat masalah yang mungkin memerlukan penyelidikan dan perubahan lebih lanjut?]

# %%
# Mendapatkan informasi data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21525 entries, 0 to 21524
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   children          21525 non-null  int64
#  1   days_employed     19351 non-null  float64
#  2   dob_years         21525 non-null  int64
#  3   education         21525 non-null  object
#  4   education_id      21525 non-null  int64
#  5   family_status     21525 non-null  object
#  6   family_status_id  21525 non-null  int64
#  7   gender            21525 non-null  object
#  8   income_type       21525 non-null  object
#  9   debt              21525 non-null  int64
#  10  total_income      19351 non-null  float64
#  11  purpose           21525 non-null  object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 2.0+ MB

# %% [markdown]
# [Apakah terdapat nilai-nilai yang hilang di semua kolom atau hanya beberapa? Jelaskan secara singkat apa yang Anda amati dalam 1-2 kalimat.]

# %% [markdown]
# Ya, terdapat nilai yang hilang pada kolom `days_employed` dan `total_income`.

# %%
# Mari kita melihat tabel yang telah difilter dengan nilai yang hilang di kolom pertama dengan data yang hilang
df[df['days_employed'].isna()].head(10)
# Out:
#     children  days_employed  dob_years            education  education_id  \
# 12         0            NaN         65  secondary education             1
# 26         0            NaN         41  secondary education             1
# 29         0            NaN         63  secondary education             1
# 41         0            NaN         50  secondary education             1
# 55         0            NaN         54  secondary education             1
# 65         0            NaN         21  secondary education             1
# 67         0            NaN         52    bachelor's degree             0
# 72         1            NaN         32    bachelor's degree             0
# 82         2            NaN         50    bachelor's degree             0
# 83         0            NaN         52  secondary education             1
#
#         family_status  family_status_id gender    income_type  debt  \
# 12  civil partnership                 1      M        retiree     0
# 26            married                 0      M  civil servant     0
# 29          unmarried                 4      F        retiree     0
# 41            married                 0      F  civil servant     0
# 55  civil partnership                 1      F        retiree     1
# 65          unmarried                 4      M       business     0
# 67            married                 0      F        retiree     0
# 72            married                 0      M  civil servant     0
# 82            married                 0      F       employee     0
# 83            married                 0      M       employee     0
#
#     total_income                                   purpose
# 12           NaN                         to have a wedding
# 26           NaN                                 education
# 29           NaN                    building a real estate
# 41           NaN                  second-hand car purchase
# 55           NaN                         to have a wedding
# 65           NaN  transactions with commercial real estate
# 67           NaN       purchase of the house for my family
# 72           NaN  transactions with commercial real estate
# 82           NaN                                   housing
# 83           NaN                                   housing

# %% [markdown]
# [Apakah nilai yang hilang tampak simetris? Apakah kita yakin dengan asumsi ini? Jelaskan pendapat Anda secara singkat di bagian ini. Anda mungkin ingin melakukan penyelidikan lebih lanjut, dan menghitung nilai yang hilang di semua baris dengan nilai yang hilang untuk memastikan bahwa sampel yang hilang memiliki ukuran yang sama.]

# %%
# Mari kita menerapkan beberapa persyaratan untuk memfilter data dan melihat jumlah baris dalam tabel yang difilter.
df_filtered_nan = df[df['days_employed'].isna()]
df_filtered_nan = df_filtered_nan[df_filtered_nan['total_income'].isna()]
df_filtered_nan.shape[0]
# Out:
# 2174

# %% [markdown]
# <div class="alert alert-success">
# <b>Reviewer's comment v1</b> <a class="tocSkip"></a>
#
# Tepat!
#
# </div>

# %% [markdown]
# **Kesimpulan menengah**
#
# [Apakah jumlah baris dalam tabel yang difilter sesuai dengan jumlah nilai yang hilang? Kesimpulan apa yang bisa kita buat dari hal ini?]
#
# Ya, jumlah nilai hilang sama dengan jumlah tabel yang difilter. Artinya nilai yang hilang dari tabel yang difilter simetris.
#
# [Hitung persentase nilai yang hilang yang dibandingkan dengan seluruh kumpulan data. Apakah ini merupakan bagian data yang sangat besar? Jika demikian, Anda mungkin ingin mengisi nilai yang hilang. Untuk melakukannya, pertama-tama kita harus mempertimbangkan apakah data yang hilang bisa jadi disebabkan oleh karakteristik klien tertentu, seperti jenis pekerjaan atau yang lainnya. Anda perlu memutuskan karakteristik mana yang *Anda* pikir mungkin menjadi alasannya. Kedua, kita harus memeriksa apakah terdapat ketergantungan nilai yang hilang pada nilai indikator lain dengan kolom yang berisi karakteristik klien spesifik yang teridentifikasi.]
#
# [Jelaskan langkah Anda selanjutnya dan bagaimana hubungannya dengan kesimpulan yang Anda buat sejauh ini.]

# %%
# Mari kita memeriksa klien yang tidak memiliki data tentang karakteristik yang teridentifikasi dan kolom dengan nilai yang hilang
df_filtered_nan.head(10)
# Out:
#     children  days_employed  dob_years            education  education_id  \
# 12         0            NaN         65  secondary education             1
# 26         0            NaN         41  secondary education             1
# 29         0            NaN         63  secondary education             1
# 41         0            NaN         50  secondary education             1
# 55         0            NaN         54  secondary education             1
# 65         0            NaN         21  secondary education             1
# 67         0            NaN         52    bachelor's degree             0
# 72         1            NaN         32    bachelor's degree             0
# 82         2            NaN         50    bachelor's degree             0
# 83         0            NaN         52  secondary education             1
#
#         family_status  family_status_id gender    income_type  debt  \
# 12  civil partnership                 1      M        retiree     0
# 26            married                 0      M  civil servant     0
# 29          unmarried                 4      F        retiree     0
# 41            married                 0      F  civil servant     0
# 55  civil partnership                 1      F        retiree     1
# 65          unmarried                 4      M       business     0
# 67            married                 0      F        retiree     0
# 72            married                 0      M  civil servant     0
# 82            married                 0      F       employee     0
# 83            married                 0      M       employee     0
#
#     total_income                                   purpose
# 12           NaN                         to have a wedding
# 26           NaN                                 education
# 29           NaN                    building a real estate
# 41           NaN                  second-hand car purchase
# 55           NaN                         to have a wedding
# 65           NaN  transactions with commercial real estate
# 67           NaN       purchase of the house for my family
# 72           NaN  transactions with commercial real estate
# 82           NaN                                   housing
# 83           NaN                                   housing

# %%
# Memeriksa distribusi
df_distribution_nan = df_filtered_nan.shape[0] / df['days_employed'].shape[0] 
print(f'Distribusi nilai yang hilang sebesar: {df_distribution_nan:0%}')
# Out:
# Distribusi nilai yang hilang sebesar: 10.099884%

# %% [markdown]
# <div class="alert alert-warning">
# <b>Reviewer's comment v1</b> <a class="tocSkip"></a>
#
# Mungkin dalam tahap ini dapat dilakukan pengecekan distribusi atau proporsi pada `df_filtered` di kolom `income_type`.
#
# </div>

# %% [markdown]
# [Deksripsikan yang Anda temukan di sini.]
#
# Nilai yang hilang sebesar `10%` artinya cukup berpengaruh terhadap dataset.
#
# **Kemungkinan penyebab hilangnya nilai dalam data**
#
# [Ajukan ide-ide Anda tentang mengapa menurut Anda nilai-nilai tersebut kemungkinan hilang. Apakah menurut Anda mereka hilang secara acak atau terdapat pola?]
#
# Belum dapat ditentukan penyebab nilai yang hilang, sehingga memerlukan analisa lebih lanjut.
#
# [Mari kita mulai memeriksa apakah nilai hilang secara acak.]

# %%
# Memeriksa distribusi di seluruh dataset
df_distribution_nan = df_filtered_nan.shape[0] / df.shape[0] 
print(f'Distribusi nilai yang hilang di seluruh dataset sebesar: {df_distribution_nan:0%}')
# Out:
# Distribusi nilai yang hilang di seluruh dataset sebesar: 10.099884%

# %% [markdown]
# <div class="alert alert-warning">
# <b>Reviewer's comment v1</b> <a class="tocSkip"></a>
#
# Lanjutan dari komen sebelumnya dapat dibandingkan dengan pengecekan distribusi atau proporsi kolom `income_type` di data sebelum di filter.
#
# </div>

# %% [markdown]
# **Kesimpulan menengah**
#
# [Apakah distribusi dalam dataset yang asli mirip dengan distribusi tabel yang telah difilter? Apa artinya itu untuk kita?]
#
# Ya, jumlah nilai yang hilang dalam dataset mirip dengan tabel yang difilter.
#
# [Jika menurut Anda kita belum dapat membuat kesimpulan apa pun, mari kembali menyelidiki dataset kita lebih lanjut. Mari kita pikirkan alasan lain yang dapat menyebabkan data hilang dan periksa apakah kita dapat menemukan pola yang dapat membuat kita berpikir bahwa nilai yang hilang tidaklah secara acak. Karena ini merupakan pekerjaan Anda, bagian ini adalah bagian opsional.]

# %%
# Periksa penyebab dan pola lain yang dapat mengakibatkan nilai yang hilang
df_filtered_nan['family_status'].value_counts()
# Out:
# married              1237
# civil partnership     442
# unmarried             288
# divorced              112
# widow / widower        95
# Name: family_status, dtype: int64

# %% [markdown]
# **Kesimpulan menengah**
#
# [Apakah pada akhirnya kita dapat memastikan bahwa nilai yang hilang adalah suatu kebetulan? Periksa hal lain yang menurut Anda penting di sini.]

# %% [markdown]
# <div class="alert alert-danger">
# <b>Reviewer's comment v1</b> <a class="tocSkip"></a>
#
# Tidak dijawab.
#
# </div>

# %%
# Memeriksa pola lainnya - jelaskan pola tersebut
df_filtered_nan['income_type'].value_counts()
# Out:
# employee         1105
# business          508
# retiree           413
# civil servant     147
# entrepreneur        1
# Name: income_type, dtype: int64

# %% [markdown]
# <div class="alert alert-warning">
# <b>Reviewer's comment v1</b> <a class="tocSkip"></a>
#
# Sebaiknya dilakukan eksplorasi lebih dalam apakah ada pola tertentu panda beberapa pekerjaan yang biasanya tidak menerima penghasilan seperti `student`, `paternity/maternity leave`, `unemployed`, serta yang tidak menentu seperti `entrepreneur`.
# </div>

# %% [markdown]
# **Kesimpulan**
#
# [Apakah Anda menemukan suatu pola? Bagaimana Anda mendapatkan kesimpulan ini?]
#
# [Jelaskan bagaimana Anda akan mengatasi nilai-nilai yang hilang. Mempertimbangkan kategori yang nilainya tidak ada.]
#
# [Buatlah perencanaan secara singkat langkah Anda selanjutnya untuk mengubah data. Anda mungkin perlu mengatasi berbagai jenis masalah: duplikat, register yang berbeda, data lama yang salah, dan nilai yang hilang.]

# %% [markdown]
# <div class="alert alert-danger">
# <b>Reviewer's comment v1</b> <a class="tocSkip"></a>
#
# Tidak dijawab.
#
# </div>

# %% [markdown]
# ## Transformasi data
#
# [Mari kita perhatikan setiap kolom untuk melihat masalah apa yang mungkin kita miliki di dalamnya.]
#
# [Mulailah dengan menghapus duplikat dan memperbaiki informasi pendidikan jika diperlukan.]

# %%
# Mari kita lihat semua nilai di kolom pendidikan untuk memeriksa ejaan apa yang perlu diperbaiki
df['education'].value_counts()
# Out:
# secondary education    13750
# bachelor's degree       4718
# SECONDARY EDUCATION      772
# Secondary Education      711
# some college             668
# BACHELOR'S DEGREE        274
# Bachelor's Degree        268
# primary education        250
# Some College              47
# SOME COLLEGE              29
# PRIMARY EDUCATION         17
# Primary Education         15
# graduate degree            4
# GRADUATE DEGREE            1
# Graduate Degree            1
# Name: education, dtype: int64

# %%
# Perbaiki register jika diperlukan
df['education'] = df['education'].str.lower()

# %%
# Memeriksa semua nilai di kolom untuk memastikan kita telah memperbaikinya
df['education'].value_counts()
# Out:
# secondary education    15233
# bachelor's degree       5260
# some college             744
# primary education        282
# graduate degree            6
# Name: education, dtype: int64

# %% [markdown]
# [Periksa data kolom `children`]

# %%
# Mari kita lihat distribusi nilai pada kolom `children`
df['children'].value_counts()
# Out:
#  0     14149
#  1      4818
#  2      2055
#  3       330
#  20       76
# -1        47
#  4        41
#  5         9
# Name: children, dtype: int64

# %% [markdown]
# [Apakah terdapat hal-hal aneh di kolom? Jika jawabannya iya, seberapa tinggi persentase data yang bermasalah? Bagaimana mereka bisa terjadi? Buat keputusan tentang apa yang akan Anda lakukan dengan data ini dan jelaskan alasannya.]
#
# Ya, terdapat value yang menunjukkan angka -1 dan 20 yang saya nilai tidak mungkin.
# <br>Kita asumsikan nilai yang bermasalah terjadi karena kesalahan input/typo.
# <br>Kita akan me-replace nilai -1 menjadi 1 dan 20 menjadi 2.

# %% [markdown]
# <div class="alert alert-success">
# <b>Reviewer's comment v1</b> <a class="tocSkip"></a>
#
# Poin yang bagus!
#
# </div>

# %%
# [perbaiki data berdasarkan keputusan Anda]
df_child_problem_value = (df['children'] == -1).sum() + (df['children'] == 20).sum()
print(df_child_problem_value)

df_child_prob_percent = df_child_problem_value / df.shape[0]
print(f'Persentase data yang bermasalah adalah: {df_child_prob_percent:.2%}')
# Out:
# 123
# Persentase data yang bermasalah adalah: 0.57%

# %%
df.loc[df['children'] == -1, 'children'] = 1 
df.loc[df['children'] == 20, 'children'] = 2

# %%
# Periksa kembali kolom `children` untuk memastikan semua telah diperbaiki
df['children'].value_counts()
# Out:
# 0    14149
# 1     4865
# 2     2131
# 3      330
# 4       41
# 5        9
# Name: children, dtype: int64

# %%
df[df['income_type'] == 'retiree']
# Out:
#        children  days_employed  dob_years            education  education_id  \
# 4             0  340266.072047         53  secondary education             1
# 12            0            NaN         65  secondary education             1
# 18            0  400281.136913         53  secondary education             1
# 24            1  338551.952911         57  secondary education             1
# 25            0  363548.489348         67  secondary education             1
# ...         ...            ...        ...                  ...           ...
# 21505         0  338904.866406         53  secondary education             1
# 21508         0  386497.714078         62  secondary education             1
# 21509         0  362161.054124         59    bachelor's degree             0
# 21518         0  373995.710838         59  secondary education             1
# 21521         0  343937.404131         67  secondary education             1
#
#            family_status  family_status_id gender income_type  debt  \
# 4      civil partnership                 1      F     retiree     0
# 12     civil partnership                 1      M     retiree     0
# 18       widow / widower                 2      F     retiree     0
# 24             unmarried                 4      F     retiree     0
# 25               married                 0      M     retiree     0
# ...                  ...               ...    ...         ...   ...
# 21505  civil partnership                 1      M     retiree     0
# 21508            married                 0      M     retiree     0
# 21509            married                 0      M     retiree     0
# 21518            married                 0      F     retiree     0
# 21521            married                 0      F     retiree     0
#
#        total_income                                   purpose
# 4         25378.572                         to have a wedding
# 12              NaN                         to have a wedding
# 18         9091.804                  buying a second-hand car
# 24        46487.558  transactions with commercial real estate
# 25         8818.041                           buy real estate
# ...             ...                                       ...
# 21505     12070.399                         to have a wedding
# 21508     11622.175                                  property
# 21509     11684.650                  real estate transactions
# 21518     24618.344                         purchase of a car
# 21521     24959.969                         purchase of a car
#
# [3856 rows x 12 columns]

# %% [markdown]
# [Periksa data dalam kolom the `days_employed`. Pertama-tama pikirkan tentang masalah apa yang mungkin ada dan apa yang mungkin ingin Anda periksa dan bagaimana Anda akan melakukannya.]

# %%
# Temukan data yang bermasalah di `days_employed`, jika terdapat masalah, dan hitung persentasenya
print(df['days_employed'].describe())

print()

df_days_employed_median = df.groupby(['income_type'])['days_employed'].median()
print(df_days_employed_median)

print()

df_days_employed_problem_value = (df['days_employed'] < 0).sum() + (df['days_employed'] > 21600).sum()
print(df_days_employed_problem_value)

print()

df_days_employed_prob_percent = df_days_employed_problem_value / df.shape[0]
print(f'Persentase data yang bermasalah adalah: {df_days_employed_prob_percent:.2%}')
# Out:
# count     19351.000000
# mean      63046.497661
# std      140827.311974
# min      -18388.949901
# 25%       -2747.423625
# 50%       -1203.369529
# 75%        -291.095954
# max      401755.400475
# Name: days_employed, dtype: float64
#
# income_type
# business                        -1547.382223
# civil servant                   -2689.368353
# employee                        -1574.202821
# entrepreneur                     -520.848083
# paternity / maternity leave     -3296.759962
# retiree                        365213.306266
# student                          -578.751554
# unemployed                     366413.652744
# Name: days_employed, dtype: float64
#
# 19351
#
# Persentase data yang bermasalah adalah: 89.90%

# %% [markdown]
# [Jika jumlah data yang bermasalah tinggi, hal tersebut mungkin dikarenakan beberapa masalah teknis. Kami mungkin ingin mengusulkan alasan paling jelas mengapa hal tersebut dapat terjadi dan bagaimanakah kemungkinan data yang benar, karena kita tidak dapat menghapus baris yang bermasalah ini.]
#
# Terdapat masalah yang sangat tinggi pada kolom `days_employed`, jika kita melihat nilai negatif sudah berdampak besar dalam dataset karena itu sama saja dengan nilai yang hilang, lalu bagaimana dengan nilai yang terlampau tinggi, tidak ada seorangpun bekerja melebihi usianya sendiri.
# <br>Karena nilai mungkin terjadi karena kesalah teknis dalam penambahan tanda `-` jadi solusi yang dapat saya lakukan adalah dengan dengan mengganti angka negatif menjadi positif.
# <br>Kemudian untuk nilai yang terlampau tinggi yang saya asumsikan hanya terjadi pada pada `kategori`, `retiree` dan `unemployed` maka saya putuskan untuk mengganti nilai tersebut dengan `0` dengan batas `21600 hari atau 59 tahun`.

# %%
# Atasi nilai yang bermasalah, jika ada
df['days_employed'] = df['days_employed'].abs()
df.loc[df['days_employed'] > 21600, 'days_employed'] = 0

# %%
# Periksa hasilnya - pastikan telah diperbaiki
print(df['days_employed'].describe())
print()
(df['days_employed'] < 0).sum()
# Out:
# count    19351.000000
# mean      1934.115623
# std       2274.751213
# min          0.000000
# 25%        291.095954
# 50%       1203.369529
# 75%       2747.423625
# max      18388.949901
# Name: days_employed, dtype: float64
# 0

# %% [markdown]
# <div class="alert alert-success">
# <b>Reviewer's comment v1</b> <a class="tocSkip"></a>
#
# OK!
#
# </div>

# %% [markdown]
# [Sekarang mari kita melihat usia klien dan apakah terdapat masalah di sana. Sekali lagi, pikirkan tentang data apakah yang dapat menjadi suatu kejanggalan pada kolom ini, yaitu berapa usia seseorang.]
#
# Ya, terdapat masalah pada kolom `usia` yaitu tidak seseorang yang bekerja sejak usia `0`

# %%
# Periksa `dob_years` untuk nilai yang mencurigakan dan hitung persentasenya
print(df['dob_years'].value_counts().sort_index())
print()
df_days_employed_prob_percent = (df['dob_years'] == 0).sum() / df.shape[0]
print(f'Persentase data yang bermasalah adalah: {df_days_employed_prob_percent:.2%}')
# Out:
# 0     101
# 19     14
# 20     51
# 21    111
# 22    183
# 23    254
# 24    264
# 25    357
# 26    408
# 27    493
# 28    503
# 29    545
# 30    540
# 31    560
# 32    510
# 33    581
# 34    603
# 35    617
# 36    555
# 37    537
# 38    598
# 39    573
# 40    609
# 41    607
# 42    597
# 43    513
# 44    547
# 45    497
# 46    475
# 47    480
# 48    538
# 49    508
# 50    514
# 51    448
# 52    484
# 53    459
# 54    479
# 55    443
# 56    487
# 57    460
# 58    461
# 59    444
# 60    377
# 61    355
# 62    352
# 63    269
# 64    265
# 65    194
# 66    183
# 67    167
# 68     99
# 69     85
# 70     65
# 71     58
# 72     33
# 73      8
# 74      6
# 75      1
# Name: dob_years, dtype: int64
#
# Persentase data yang bermasalah adalah: 0.47%

# %% [markdown]
# [Putuskan apa yang akan Anda lakukan dengan nilai yang bermasalah dan jelaskan alasannya.]
#
# Saya akan mengganti value `0` di kolom `age`, dengan `median` dari usia.
# <br>Karena tiap klien yang memiliki usia `0` memiliki karakteristik yang berbeda.

# %%
# Atasi masalah pada kolom `dob_years`, jika terdapat masalah
avg_dob_years = df['dob_years'].median() 
df.loc[df['dob_years'] == 0, 'dob_years'] = avg_dob_years

# %%
# Periksa hasilnya - pastikan telah diperbaiki
df[df['dob_years'] == 0].shape[0]
# Out:
# 0

# %% [markdown]
# [Sekarang saatnya memeriksa kolom `family_status`. Lihat nilai seperti apakah yang terdapat di kolom dan masalah apa yang mungkin perlu Anda atasi.]

# %%
# Mari kita lihat nilai untuk kolom
df['family_status'].value_counts()
# Out:
# married              12380
# civil partnership     4177
# unmarried             2813
# divorced              1195
# widow / widower        960
# Name: family_status, dtype: int64

# %%
# Atasi nilai yang bermasalah di `family_status`, jika ada
print('Tidak terdapat masalah')
# Out:
# Tidak terdapat masalah

# %%
# Periksa hasilnya - pastikan nilai telah diperbaiki
df['family_status'].value_counts()
# Out:
# married              12380
# civil partnership     4177
# unmarried             2813
# divorced              1195
# widow / widower        960
# Name: family_status, dtype: int64

# %% [markdown]
# [Sekarang saatnya memeriksa kolom `gender`. Lihat nilai seperti apakah yang terdapat di kolom dan masalah apa yang mungkin perlu Anda atasi.]
#
# Terdapat satu masalah yaitu pada value `XNA`
# <br>Sulit untuk megidentifikasi untuk mengganti value tersebut, dan saya putuskan untuk menghapus 1 baris tersebut

# %%
# Mari kita melihat nilainya di kolom
df['gender'].value_counts()
# Out:
# F      14236
# M       7288
# XNA        1
# Name: gender, dtype: int64

# %%
df[df['gender'] == 'XNA']
# Out:
#        children  days_employed  dob_years     education  education_id  \
# 10701         0    2358.600502       24.0  some college             2
#
#            family_status  family_status_id gender income_type  debt  \
# 10701  civil partnership                 1    XNA    business     0
#
#        total_income          purpose
# 10701     32624.825  buy real estate

# %%
# Atasi nilai-nilai yang bermasalah, jika ada
df = df.loc[df["gender"] != 'XNA']

# %%
# Periksa hasilnya - pastikan telah diperbaiki
df['gender'].value_counts()
# Out:
# F    14236
# M     7288
# Name: gender, dtype: int64

# %% [markdown]
# [Sekarang saatnya memeriksa kolom `income_type`. Lihat nilai seperti apakah yang terdapat di kolom dan masalah apa yang mungkin perlu Anda atasi.]

# %%
# Mari kita lihat nilai dalam kolom
df['income_type'].value_counts()
# Out:
# employee                       11119
# business                        5084
# retiree                         3856
# civil servant                   1459
# entrepreneur                       2
# unemployed                         2
# paternity / maternity leave        1
# student                            1
# Name: income_type, dtype: int64

# %%
# Atasi nilai yang bermasalah, jika ada
print('Tidak terdapat masalah')
# Out:
# Tidak terdapat masalah

# %%
# Periksa hasilnya - pastikan telah diperbaiki
df['income_type'].value_counts()
# Out:
# employee                       11119
# business                        5084
# retiree                         3856
# civil servant                   1459
# entrepreneur                       2
# unemployed                         2
# paternity / maternity leave        1
# student                            1
# Name: income_type, dtype: int64

# %% [markdown]
# [Sekarang saatnya melihat apakah terdapat duplikasi di dalam data kita. Jika kita menemukannya, Anda harus memutuskan apa yang akan Anda lakukan dengan duplikat tersebut dan menjelaskan alasannya.]

# %%
# Memeriksa duplikat
df.duplicated().sum()
# Out:
# 72

# %%
# Atasi duplikat, jika ada
df = df.drop_duplicates().reset_index(drop=True)

# %%
# Terakhir periksa apakah kita memiliki duplikat
df.duplicated().sum()
# Out:
# 0

# %%
# Periksa ukuran dataset yang sekarang Anda miliki setelah manipulasi pertama yang Anda lakukan
df.shape
# Out:
# (21452, 12)

# %%
old_df_shape = 21525
df_shape_percentage = (old_df_shape - df.shape[0]) / old_df_shape
print(f'Persentase dari perubahan dalam dateset adalah: {df_shape_percentage:.2%}')
# Out:
# Persentase dari perubahan dalam dateset adalah: 0.34%

# %% [markdown]
# [Jelaskan dataset baru Anda: jelaskan secara singkat apa perubahannya dan berapa persentase perubahannya, jika ada.]

# %% [markdown]
# # Bekerja dengan nilai yang hilang

# %% [markdown]
# [Untuk mempercepat pekerjaan dengan beberapa data, Anda mungkin ingin menggunakan dictionary untuk beberapa nilai, di mana tersedia ID. Jelaskan mengapa dan dictionary apakah yang akan Anda gunakan.]

# %%
# Temukan dictionary
import numpy as np

# %% [markdown]
# ### Memperbaiki nilai yang hilang di `total_income`

# %% [markdown]
# [Jelaskan secara singkat kolom manakah yang memiliki nilai yang hilang yang perlu Anda tangani. Jelaskan bagaimana Anda akan memperbaikinya.]
#
#
# [Mulailah dengan mengatasi nilai pendapatan total yang hilang. Membuat kategori usia untuk klien. Membuat kolom baru dengan kategori usia. Strategi ini dapat dibantu dengan menghitung nilai pendapatan total.]

# %%
# Mari menulis fungsi untuk menghitung kategori usia
def age_group(age):
 
    if age <= 30:
        return 'young adult'
    elif age <= 45:
        return 'adult'
    elif age <= 64:
        return 'middle age'
    else:
        return 'retired'

# %%
# Lakukan pengujian apakah fungsi bekerja atau tidak
print(age_group(23))
print(age_group(38))
print(age_group(46))
print(age_group(70))
# Out:
# young adult
# adult
# middle age
# retired

# %%
# Membuat kolom baru berdasarkan fungsi
df['age_group'] = df['dob_years'].apply(age_group)

# %%
# Memeriksa bagaimana nilai di dalam kolom baru
df.tail(10)
# Out:
#        children  days_employed  dob_years            education  education_id  \
# 21442         1     467.685130       28.0  secondary education             1
# 21443         0     914.391429       42.0    bachelor's degree             0
# 21444         0     404.679034       42.0    bachelor's degree             0
# 21445         0       0.000000       59.0  secondary education             1
# 21446         1    2351.431934       37.0      graduate degree             4
# 21447         1    4529.316663       43.0  secondary education             1
# 21448         0       0.000000       67.0  secondary education             1
# 21449         1    2113.346888       38.0  secondary education             1
# 21450         3    3112.481705       38.0  secondary education             1
# 21451         2    1984.507589       40.0  secondary education             1
#
#            family_status  family_status_id gender income_type  debt  \
# 21442            married                 0      F    employee     1
# 21443            married                 0      F    business     0
# 21444  civil partnership                 1      F    business     0
# 21445            married                 0      F     retiree     0
# 21446           divorced                 3      M    employee     0
# 21447  civil partnership                 1      F    business     0
# 21448            married                 0      F     retiree     0
# 21449  civil partnership                 1      M    employee     1
# 21450            married                 0      M    employee     1
# 21451            married                 0      F    employee     0
#
#        total_income                     purpose    age_group
# 21442     17517.812          to become educated  young adult
# 21443     51649.244    purchase of my own house        adult
# 21444     28489.529           buying my own car        adult
# 21445     24618.344           purchase of a car   middle age
# 21446     18551.846  buy commercial real estate        adult
# 21447     35966.698        housing transactions        adult
# 21448     24959.969           purchase of a car      retired
# 21449     14347.610                    property        adult
# 21450     39054.888           buying my own car        adult
# 21451     13127.587                to buy a car        adult

# %% [markdown]
# [Pikirkan tentang faktor-faktor yang biasanya bergantung pada pendapatan. Akhirnya, Anda akan mengetahui apakah Anda harus menggunakan nilai rata-rata atau median untuk mengganti nilai yang hilang. Untuk membuat keputusan ini, Anda mungkin ingin melihat identifikasi distribusi faktor yang memengaruhi pendapatan seseorang.]

# %% [markdown]
# [Buat tabel yang hanya memiliki data tanpa nilai yang hilang. Data ini akan digunakan untuk memperbaiki nilai yang hilang.]

# %%
# Membuat tabel tanpa nilai yang hilang dan menampilkan beberapa barisnya untuk memastikan semuanya berjalan dengan baik
df_new_table = df[df.notna()]
df_new_table.head(10)
# Out:
#    children  days_employed  dob_years            education  education_id  \
# 0         1    8437.673028       42.0    bachelor's degree             0
# 1         1    4024.803754       36.0  secondary education             1
# 2         0    5623.422610       33.0  secondary education             1
# 3         3    4124.747207       32.0  secondary education             1
# 4         0       0.000000       53.0  secondary education             1
# 5         0     926.185831       27.0    bachelor's degree             0
# 6         0    2879.202052       43.0    bachelor's degree             0
# 7         0     152.779569       50.0  secondary education             1
# 8         2    6929.865299       35.0    bachelor's degree             0
# 9         0    2188.756445       41.0  secondary education             1
#
#        family_status  family_status_id gender income_type  debt  total_income  \
# 0            married                 0      F    employee     0     40620.102
# 1            married                 0      F    employee     0     17932.802
# 2            married                 0      M    employee     0     23341.752
# 3            married                 0      M    employee     0     42820.568
# 4  civil partnership                 1      F     retiree     0     25378.572
# 5  civil partnership                 1      M    business     0     40922.170
# 6            married                 0      F    business     0     38484.156
# 7            married                 0      M    employee     0     21731.829
# 8  civil partnership                 1      F    employee     0     15337.093
# 9            married                 0      M    employee     0     23108.150
#
#                                purpose    age_group
# 0                purchase of the house        adult
# 1                         car purchase        adult
# 2                purchase of the house        adult
# 3              supplementary education        adult
# 4                    to have a wedding   middle age
# 5                purchase of the house  young adult
# 6                 housing transactions        adult
# 7                            education   middle age
# 8                     having a wedding        adult
# 9  purchase of the house for my family        adult

# %%
# Perhatikan nilai rata-rata untuk pendapatan berdasarkan faktor yang telah Anda identifikasi
df_total_income_mean = df.groupby(['age_group'])['total_income'].mean()
df_total_income_mean
# Out:
# age_group
# adult          28463.752600
# middle age     26053.435322
# retired        21542.650450
# young adult    25815.651899
# Name: total_income, dtype: float64

# %%
# Perhatikan nilai median untuk pendapatan berdasarkan faktor yang telah Anda identifikasi
df_total_income_median = df.groupby(['age_group'])['total_income'].median()
df_total_income_median
# Out:
# age_group
# adult          24750.7935
# middle age     22535.9400
# retired        18471.3910
# young adult    22955.4740
# Name: total_income, dtype: float64

# %% [markdown]
# [Ulangi perbandingan tersebut untuk beberapa faktor. Pastikan Anda mempertimbangkan berbagai aspek dan menjelaskan proses pada saat Anda berpikir.]

# %% [markdown]
# [Buat keputusan tentang karakteristik yang paling menentukan pendapatan dan apakah Anda akan menggunakan median atau mean. Jelaskan mengapa Anda membuat keputusan ini]

# %%
#  Tulis fungsi yang akan kita gunakan untuk mengisi nilai yang hilang
income1 = df_total_income_median['young adult']        
income2 = df_total_income_median['adult']
income3 = df_total_income_median['middle age']
income4 = df_total_income_median['retired']

def total_income_fillna(age_group):
    
    if age_group == 'young adult':
        return income1
    elif age_group == 'adult':
        return income2
    elif age_group == 'middle age':
        return income3
    else:
        return income4

# %%
# Memeriksa bagaimana nilai di dalam kolom baru
print(total_income_fillna('young adult'))
print(total_income_fillna('adult'))
print(total_income_fillna('middle age'))
print(total_income_fillna('retired'))
# Out:
# 22955.474
# 24750.7935
# 22535.94
# 18471.391000000003

# %%
# Terapkan fungsi ke setiap baris
df['tot_revenue'] = df['total_income'].apply(total_income_fillna)

# %%
# Periksa apakah kita mendapatkan kesalahan
df['total_income'].isna().sum()
# Out:
# 2102

# %% [markdown]
# [Jika Anda menemukan kesalahan dalam menyiapkan nilai data yang hilang, artinya mungkin terdapat sesuatu yang khusus terkait dengan data untuk kategori tersebut. Mari pikirkan - Anda mungkin ingin memperbaiki beberapa hal secara manual, jika terdapat cukup data untuk menemukan median/rata-rata.]

# %%
# Mengganti nilai yang hilang jika terdapat kesalahan
df['total_income'].fillna(df['tot_revenue'], inplace=True)

# %% [markdown]
# [Ketika Anda berpikir Anda telah selesai dengan `total_income`, periksa apakah jumlah total nilai di kolom ini sesuai dengan jumlah nilai di kolom lain.]
#
# Ya, jumlah kolom `total_income` sama dengan jumlah pada kolom lainnya.

# %%
# Memeriksa jumlah entri di kolom
df.drop(df.columns[[13]], axis=1, inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21452 entries, 0 to 21451
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   children          21452 non-null  int64
#  1   days_employed     19350 non-null  float64
#  2   dob_years         21452 non-null  float64
#  3   education         21452 non-null  object
#  4   education_id      21452 non-null  int64
#  5   family_status     21452 non-null  object
#  6   family_status_id  21452 non-null  int64
#  7   gender            21452 non-null  object
#  8   income_type       21452 non-null  object
#  9   debt              21452 non-null  int64
#  10  total_income      21452 non-null  float64
#  11  purpose           21452 non-null  object
#  12  age_group         21452 non-null  object
# dtypes: float64(3), int64(4), object(6)
# memory usage: 2.1+ MB

# %% [markdown]
# ###  Memperbaiki nilai di `days_employed`

# %% [markdown]
# [Pikirkan tentang parameter yang dapat membantu Anda memperbaiki nilai yang hilang di kolom ini. Akhirnya, Anda akan mengetahui apakah Anda harus menggunakan nilai rata-rata atau median untuk mengganti nilai yang hilang. Anda mungkin akan melakukan penelitian yang sama dengan yang Anda lakukan saat memperbaiki data di kolom sebelumnya.]

# %%
# Distribusi median dari `days_employed` berdasarkan parameter yang Anda identifikasi
df_days_employed_median = df.groupby(['age_group'])['days_employed'].median()
df_days_employed_median.sort_values()
# Out:
# age_group
# retired           0.000000
# middle age      886.435508
# young adult    1041.692949
# adult          1684.470914
# Name: days_employed, dtype: float64

# %%
# Distribusi rata-rata dari `days_employed` berdasarkan parameter yang Anda identifikasi
df_days_employed_mean = df.groupby(['age_group'])['days_employed'].mean()
df_days_employed_mean.sort_values()
# Out:
# age_group
# retired         573.625877
# young adult    1276.700146
# middle age     2057.039353
# adult          2245.364732
# Name: days_employed, dtype: float64

# %% [markdown]
# [Tentukan apa yang akan Anda gunakan: rata-rata atau median. Jelaskan mengapa.]

# %%
# Mari tulis fungsi yang menghitung rata-rata atau median (tergantung keputusan Anda) berdasarkan parameter yang Anda identifikasi
days1 = df_days_employed_mean['young adult']    
days2 = df_days_employed_mean['adult']
days3 = df_days_employed_mean['middle age']
days4 = df_days_employed_mean['retired']

def days_employed_fillna(income_type):
    
    if income_type == 'young adult':
        return days1
    elif income_type == 'adult':
        return days2
    elif income_type == 'middle age':
        return days3
    else:
        return days4

# %%
# Periksa bahwa fungsi bekerja
print(days_employed_fillna('young adult'))
print(days_employed_fillna('adult'))
print(days_employed_fillna('middle age'))
print(days_employed_fillna('retired'))
# Out:
# 1276.7001461695133
# 2245.364731938934
# 2057.039352870257
# 573.625877420218

# %%
# Terapkan fungsi ke income_type
df['days_experience'] = df['days_employed'].apply(days_employed_fillna)

# %%
# Periksa bahwa fungsi bekerja
df['days_employed'].isna().sum()
# Out:
# 2102

# %%
# Mengganti nilai yang hilang
df['days_employed'].fillna(df['days_experience'], inplace=True)
df['days_employed'] = np.where(df['days_employed'] == 0, df['days_experience'], df['days_employed'])

# %% [markdown]
# [Ketika Anda berpikir bahwa Anda telah selesai dengan `total_income`, periksa apakah jumlah total nilai di kolom ini sesuai dengan jumlah nilai di kolom lain.]

# %%
# Periksa entri di semua kolom - pastikan kita memperbaiki semua nilai yang hilang
df.drop(df.columns[[13]], axis=1, inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21452 entries, 0 to 21451
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   children          21452 non-null  int64
#  1   days_employed     21452 non-null  float64
#  2   dob_years         21452 non-null  float64
#  3   education         21452 non-null  object
#  4   education_id      21452 non-null  int64
#  5   family_status     21452 non-null  object
#  6   family_status_id  21452 non-null  int64
#  7   gender            21452 non-null  object
#  8   income_type       21452 non-null  object
#  9   debt              21452 non-null  int64
#  10  total_income      21452 non-null  float64
#  11  purpose           21452 non-null  object
#  12  age_group         21452 non-null  object
# dtypes: float64(3), int64(4), object(6)
# memory usage: 2.1+ MB

# %% [markdown]
# ## Pengkategorian Data
#
# [Untuk menjawab pertanyaan dan menguji hipotesis, Anda akan bekerja dengan data yang telah dikategorikan. Lihatlah pertanyaan-pertanyaan yang diajukan kepada Anda dan yang harus Anda jawab. Pikirkan tentang data mana yang perlu dikategorikan untuk menjawab pertanyaan-pertanyaan ini. Di bawah ini Anda akan menemukan template di mana Anda dapat bekerja dengan cara Anda sendiri saat mengkategorikan data. Proses pertama adalah menutup data teks; yang kedua mengatasi data numerik yang perlu dikategorikan. Anda dapat menggunakan keduanya atau tidak sama sekali dari petunjuk yang disarankan - terserah Anda.]
#
# [Terlepas dari keputusan Anda untuk mengatasi pengkategorian, pastikan secara jelas Anda memberikan penjelasan tentang mengapa Anda membuat keputusan tersebut. Ingat: ini merupakan pekerjaan Anda dan semua di dalamnya adalah keputusan Anda.]

# %%
# Tampilkan nilai data yang Anda pilih untuk pengkategorian
df['purpose'].value_counts()
# Out:
# wedding ceremony                            791
# having a wedding                            767
# to have a wedding                           765
# real estate transactions                    675
# buy commercial real estate                  661
# housing transactions                        652
# buying property for renting out             651
# transactions with commercial real estate    650
# housing                                     646
# purchase of the house                       646
# purchase of the house for my family         638
# construction of own property                635
# property                                    633
# transactions with my real estate            627
# building a real estate                      624
# buy real estate                             620
# purchase of my own house                    620
# building a property                         619
# housing renovation                          607
# buy residential real estate                 606
# buying my own car                           505
# going to university                         496
# car                                         494
# second-hand car purchase                    486
# buying a second-hand car                    478
# cars                                        478
# to own a car                                478
# to buy a car                                471
# car purchase                                461
# supplementary education                     460
# purchase of a car                           455
# university education                        452
# education                                   447
# to get a supplementary education            446
# getting an education                        442
# profile education                           436
# getting higher education                    426
# to become educated                          408
# Name: purpose, dtype: int64

# %% [markdown]
# [Let's check unique values]

# %%
# Periksa nilai unik
df['purpose'].sort_values().unique()
# Out:
# array(['building a property', 'building a real estate',
#        'buy commercial real estate', 'buy real estate',
#        'buy residential real estate', 'buying a second-hand car',
#        'buying my own car', 'buying property for renting out', 'car',
#        'car purchase', 'cars', 'construction of own property',
#        'education', 'getting an education', 'getting higher education',
#        'going to university', 'having a wedding', 'housing',
#        'housing renovation', 'housing transactions', 'profile education',
#        'property', 'purchase of a car', 'purchase of my own house',
#        'purchase of the house', 'purchase of the house for my family',
#        'real estate transactions', 'second-hand car purchase',
#        'supplementary education', 'to become educated', 'to buy a car',
#        'to get a supplementary education', 'to have a wedding',
#        'to own a car', 'transactions with commercial real estate',
#        'transactions with my real estate', 'university education',
#        'wedding ceremony'], dtype=object)

# %% [markdown]
# [Kelompok utama apakah yang dapat Anda identifikasi berdasarkan nilai uniknya?]
#
# [Berdasarkan topik ini, kita ingin mengkategorikan data kita.]

# %%
# Mari kita menulis fungsi untuk mengkategorikan data berdasarkan topik umum
def purpose_common(purpose):
    
    if 'property' in purpose:
        return 'property'
    elif 'estate' in purpose:
        return 'property'
    elif 'hous' in purpose:
        return 'property'
    elif 'car' in purpose:
        return 'car'
    elif 'educ' in purpose:
        return 'education'
    elif 'univ' in purpose:
        return 'education'
    elif 'wedd' in purpose:
        return 'wedding'

# %%
# Buat kolom dengan kategori dan hitung nilainya
df['general_purpose'] = df['purpose'].apply(purpose_common)
print(df['general_purpose'].value_counts())
print()
df['general_purpose'].count()
# Out:
# property     10810
# car           4306
# education     4013
# wedding       2323
# Name: general_purpose, dtype: int64
# 21452

# %% [markdown]
# [Jika Anda memutuskan untuk mengkategorikan data numerik, Anda juga harus membuat kategori untuk data tersebut.]

# %%
# Lihat melalui semua data numerik di kolom yang Anda pilih untuk pengkategorian
df['total_income'].value_counts().sort_index()
# Out:
# 3306.762      1
# 3392.845      1
# 3418.824      1
# 3471.216      1
# 3503.298      1
#              ..
# 273809.483    1
# 274402.943    1
# 276204.162    1
# 352136.354    1
# 362496.645    1
# Name: total_income, Length: 19348, dtype: int64

# %%
# Mendapatkan kesimpulan statistik untuk kolomnya
df['total_income'].describe()
# Out:
# count     21452.000000
# mean      25972.425615
# std       15841.884802
# min        3306.762000
# 25%       17217.441750
# 50%       21724.967000
# 75%       31328.693750
# max      362496.645000
# Name: total_income, dtype: float64

# %% [markdown]
# [Tentukan rentang apa yang akan Anda gunakan untuk pengelompokan dan jelaskan alasannya.]

# %%
# Membuat fungsi untuk pengkategorian menjadi kelompok numerik yang berbeda berdasarkan rentang
def income_class(total_income):
 
    if total_income <= 32000:
        return 'poor'
    elif total_income <= 53000:
        return 'lower middle class'
    elif total_income <= 106000:
        return 'middle class'
    elif total_income <= 373000:
        return 'upper middle class'
    else:
        return 'rich'

# %%
# Membuat kolom dengan kategori
df['economic_class'] = df['total_income'].apply(income_class)

# %%
# Menghitung setiap nilai kategori untuk melihat pendistribusian
df['economic_class'].value_counts()
# Out:
# poor                  16387
# lower middle class     3985
# middle class           1000
# upper middle class       80
# Name: economic_class, dtype: int64

# %% [markdown]
# ## Memeriksa Hipotesis

# %% [markdown]
# **Apakah terdapat korelasi antara memiliki anak dengan membayar kembali tepat waktu?**

# %%
# Periksa data anak dan membayar kembali dengan tepat waktu
df_children_debt = df.groupby(['children', 'debt'])['debt'].count()
print(df_children_debt)
print()
# Menghitung tarif otomatis berdasarkan jumlah anak
df_children_debt_ratio = df_children_debt / df.shape[0]
df_children_debt_ratio
# Out:
# children  debt
# 0         0       13026
#           1        1063
# 1         0        4410
#           1         445
# 2         0        1926
#           1         202
# 3         0         303
#           1          27
# 4         0          37
#           1           4
# 5         0           9
# Name: debt, dtype: int64
# children  debt
# 0         0       0.607216
#           1       0.049552
# 1         0       0.205575
#           1       0.020744
# 2         0       0.089782
#           1       0.009416
# 3         0       0.014125
#           1       0.001259
# 4         0       0.001725
#           1       0.000186
# 5         0       0.000420
# Name: debt, dtype: float64

# %% [markdown]
# **Kesimpulan**
#
# [Tulis kesimpulan Anda berdasarkan manipulasi dan pengamatan Anda.]
#
# Dari data diatas klien yang paling banyak melakukan pengajuan kredit dan tidak memiliki hutang pembayaran kredit yaitu dari klien yang belum memiliki anak sebesar `60,72%`, kemudian klien yang memiliki `1` anak sebesar `29,5%`, kemudian klien yang memiliki `2` dan `3` anak masing-masing sebesar `8,9%` dan `0,14%`.

# %% [markdown]
# **Apakah terdapat korelasi antara status keluarga dengan membayar kembali tepat waktu?**

# %%
# Periksa data status keluarga dan membayar kembali dengan tepat waktu
df_family_debt = df.groupby(['family_status', 'debt'])['debt'].count()
print(df_family_debt)
print()
# Menghitung tarif otomatis berdasarkan status keluarga
df_family_debt_ratio = df_family_debt / df.shape[0]
df_family_debt_ratio
# Out:
# family_status      debt
# civil partnership  0        3761
#                    1         388
# divorced           0        1110
#                    1          85
# married            0       11408
#                    1         931
# unmarried          0        2536
#                    1         274
# widow / widower    0         896
#                    1          63
# Name: debt, dtype: int64
# family_status      debt
# civil partnership  0       0.175322
#                    1       0.018087
# divorced           0       0.051743
#                    1       0.003962
# married            0       0.531792
#                    1       0.043399
# unmarried          0       0.118217
#                    1       0.012773
# widow / widower    0       0.041768
#                    1       0.002937
# Name: debt, dtype: float64

# %% [markdown]
# **Kesimpulan**
#
# [Tulis kesimpulan Anda berdasarkan manipulasi dan pengamatan Anda.]
#
# Dari data diatas klien yang paling banyak melakukan pengajuan kredit dan tidak memiliki hutang pembayaran kredit yaitu dari klien yang sudah menikah sebesar `53,17%`, kemudian dari klien belum menikah dan tinggal bersama, masing-masing sebesar `11,82%` dan `17,53`.

# %% [markdown]
# **Apakah terdapat korelasi antara tingkat pendapatan dengan membayar kembali tepat waktu?**

# %%
# Periksa data tingkat pendapatan dan membayar kembali dengan tepat waktu
df_income_debt = df.groupby(['economic_class', 'debt'])['debt'].count()
print(df_income_debt)
print()
# Menghitung tarif otomatis berdasarkan tingkat pendapatan
df_income_debt_ratio = df_income_debt / df.shape[0]
df_income_debt_ratio
# Out:
# economic_class      debt
# lower middle class  0        3704
#                     1         281
# middle class        0         928
#                     1          72
# poor                0       15004
#                     1        1383
# upper middle class  0          75
#                     1           5
# Name: debt, dtype: int64
# economic_class      debt
# lower middle class  0       0.172665
#                     1       0.013099
# middle class        0       0.043259
#                     1       0.003356
# poor                0       0.699422
#                     1       0.064470
# upper middle class  0       0.003496
#                     1       0.000233
# Name: debt, dtype: float64

# %% [markdown]
# **Kesimpulan**
#
# [Tulis kesimpulan Anda berdasarkan manipulasi dan pengamatan Anda.]
#
# Untuk klien berdasarkan tingkat pendapatan yang paling banyak melakukan pengajuan kredit dan tidak memiliki hutang pembayaran kredit berasal dari klien dengan status `poor` sebesar `69,94%`, kemudian dari `lower middle class` sebesar `17,26%`, selanjutnya dari `middle class` dan `upper middle class` masing-masing sebesar `4%` dan `0,3%`.

# %% [markdown]
# **Bagaimana tujuan kredit memengaruhi tarif otomatis?**

# %%
# Periksa persentase tarif otomatis untuk setiap tujuan kredit dan lakukan penganalisisan
df_purpose_debt = df.groupby(['general_purpose', 'debt'])['debt'].count()
df_purpose_debt_ratio = df_purpose_debt / df.shape[0]
df_purpose_debt_ratio
# Out:
# general_purpose  debt
# car              0       0.181941
#                  1       0.018786
# education        0       0.169821
#                  1       0.017248
# property         0       0.467462
#                  1       0.036453
# wedding          0       0.099618
#                  1       0.008671
# Name: debt, dtype: float64

# %% [markdown]
# **Kesimpulan**
#
# [Tulis kesimpulan Anda berdasarkan manipulasi dan pengamatan Anda.]
#
# Dari data di atas dapat disimpulkan bahwa klien yang paling banyak melakukan pengajuan kredit dan tidak memiliki hutang pembayaran pinjaman adalah untuk keperluan `property` sebesar `46,74%`, kemudian untuk keperluan `car` dan `education` masing-masing sebesar `18,19%` dan `16,98%`, serta yang paling rendah untuk keperluan `wedding` sebesar `9%`.

# %% [markdown]
# # Kesimpulan Umum
#
# [Tuliskan kesimpulan Anda di bagian akhir ini. Pastikan Anda memasukkan semua kesimpulan penting yang telah Anda buat berkaitan dengan cara Anda memproses dan menganalisis data. Mengatasi nilai yang hilang, duplikat, dan kemungkinan alasan serta solusi untuk data lama yang bermasalah yang harus Anda tangani.]
#
# [Tuliskan kesimpulan Anda mengenai pertanyaan yang ingin Anda ajukan di sini juga.]
